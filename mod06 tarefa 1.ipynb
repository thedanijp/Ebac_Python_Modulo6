# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
import pandas as pd

# %%
brsus = pd.read_csv('sinasc_RO_2019.csv')

# %%
brsus.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
import matplotlib.pyplot as plt

# Gráfico de barras para APGAR1
brsus['APGAR1'].value_counts().plot(kind='bar')
plt.title('Frequência de APGAR1')
plt.xlabel('APGAR1')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
# Agrupando por CONSULTAS e calculando a média de APGAR5
agrupado = brsus.groupby('CONSULTAS')['APGAR5'].mean()

# Criando o gráfico de barras
agrupado.plot(kind='bar')
plt.title('APGAR5 Médio por Número de Consultas')
plt.xlabel('Número de Consultas')
plt.ylabel('APGAR5 Médio')
plt.show()

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %%
import seaborn as sns

# Criando um painel 2x2
fig, axes = plt.subplots(2, 2, figsize=(15,10))

# Plotando os gráficos em cada subplot
sns.countplot(x='SEXO', data=brsus, ax=axes[0,0])
sns.countplot(x='GESTACAO', data=brsus, ax=axes[0,1])
sns.countplot(x='ESTCIVMAE', data=brsus, ax=axes[1,0])
sns.countplot(x='CONSULTAS', data=brsus, ax=axes[1,1])

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Criando um painel 2x2
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Plotando os gráficos em cada subplot
sns.countplot(x='SEXO', data=brsus, ax=axes[0,0])
sns.countplot(x='GESTACAO', data=brsus, ax=axes[0,1])
sns.countplot(x='ESTCIVMAE', data=brsus, ax=axes[1,0])
sns.countplot(x='CONSULTAS', data=brsus, ax=axes[1,1])

# Ajustando a rotação dos rótulos do eixo x para todos os subplots
axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45, ha='right')
axes[0, 1].set_xticklabels(axes[0, 1].get_xticklabels(), rotation=45, ha='right')


plt.tight_layout()
plt.show()
# Out:
# C:\Users\morid\AppData\Local\Temp\ipykernel_98444\3529600052.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45, ha='right')
# C:\Users\morid\AppData\Local\Temp\ipykernel_98444\3529600052.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0, 1].set_xticklabels(axes[0, 1].get_xticklabels(), rotation=45, ha='right')
# C:\Users\morid\AppData\Local\Temp\ipykernel_98444\3529600052.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1, 0].set_xticklabels(axes[1, 0].get_xticklabels(), rotation=45, ha='right')
# ...
